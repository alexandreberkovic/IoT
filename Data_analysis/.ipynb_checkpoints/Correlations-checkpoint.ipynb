# %%
import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import pandas as pd
import statsmodels.api as sm
import matplotlib
from pylab import rcParams
from pathlib import Path
from scipy import stats
import seaborn as sns
from sklearn import preprocessing
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

# %%
root = Path('/Users','alexandreberkovic','Desktop', 'Year_4','SIoT','IoT')

# %%
df = pd.read_csv(root / 'Output_data/CSV/sensor.csv')

# %%
df.columns
# Out:
# Index(['Humidity', 'Temperature', 'Light', 'Time stamp', 'Date'], dtype='object')

# %%
df = df.drop('Date',axis = 1)

# %%
# time stamp column to ts instead of string
df['Time stamp'] = pd.to_datetime(df['Time stamp'], infer_datetime_format=True)

# %%
# # remove humidity levels below 30 (as those should not occur)
df = df.loc[df['Humidity'] >= 30]
# df = df.reset_index()

# %%
df = df.loc[df['Light'] >= 0]

# %%
df = df.set_index('Time stamp')

# %%
humidity = df['Humidity']
temperature = df['Temperature']
light = df['Light']

# %%
# resampling at every 10min 
# h = humidity.resample('10min').mean()

# %%
# y = y[3058:]

# %%
h = humidity.resample('10min').mean()
t = temperature.resample('10min').mean()
l = light.resample('10min').mean()

# %%
# yNew = y.fillna(method="ffill")
# yNew = y.interpolate('akima').dropna()
h = h.interpolate('akima').dropna()
t = t.interpolate('akima').dropna()
l = l.interpolate('akima').dropna()

# %%
h = h[3500:3700]
t = t[3500:3700]
l = l[3500:3700]

# %%
h.sort_index(inplace=True)
t.sort_index(inplace=True)
l.sort_index(inplace=True)
yNew.sort_index(inplace=True)

# %%
h.plot(figsize=(15, 6))
t.plot(figsize=(15, 6))
plt.show()

# %%
h
# Out:
# Time stamp
# 2021-12-08 02:00:00    64.3
# 2021-12-08 02:10:00    64.5
# 2021-12-08 02:20:00    64.7
# 2021-12-08 02:30:00    65.0
# 2021-12-08 02:40:00    65.3
#                        ...
# 2021-12-09 10:30:00    60.6
# 2021-12-09 10:40:00    60.4
# 2021-12-09 10:50:00    60.6
# 2021-12-09 11:00:00    60.5
# 2021-12-09 11:10:00    60.3
# Freq: 10T, Name: Humidity, Length: 200, dtype: float64

# %%
l = l.replace(0, 1)

# %%
h_val = h.values.reshape(-1, 1) #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
h_scaled = min_max_scaler.fit_transform(h_val)
h_norm = pd.DataFrame(h_scaled).set_index(h.index)
h_norm.columns = ['Humidity']

# %%
h_norm
# Out:
#                      Humidity
# Time stamp
# 2021-12-08 02:00:00  0.730337
# 2021-12-08 02:10:00  0.741573
# 2021-12-08 02:20:00  0.752809
# 2021-12-08 02:30:00  0.769663
# 2021-12-08 02:40:00  0.786517
# ...                       ...
# 2021-12-09 10:30:00  0.522472
# 2021-12-09 10:40:00  0.511236
# 2021-12-09 10:50:00  0.522472
# 2021-12-09 11:00:00  0.516854
# 2021-12-09 11:10:00  0.505618
#
# [200 rows x 1 columns]

# %%
h_norm
# Out:
#                      Humidity
# Time stamp
# 2021-12-08 02:00:00  0.730337
# 2021-12-08 02:10:00  0.741573
# 2021-12-08 02:20:00  0.752809
# 2021-12-08 02:30:00  0.769663
# 2021-12-08 02:40:00  0.786517
# ...                       ...
# 2021-12-09 10:30:00  0.522472
# 2021-12-09 10:40:00  0.511236
# 2021-12-09 10:50:00  0.522472
# 2021-12-09 11:00:00  0.516854
# 2021-12-09 11:10:00  0.505618
#
# [200 rows x 1 columns]

# %%
t_val = t.values.reshape(-1, 1) #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
t_scaled = min_max_scaler.fit_transform(t_val)
t_norm = pd.DataFrame(t_scaled).set_index(h.index)
t_norm.columns = ['Temperature']

# %%
l_val = l.values.reshape(-1, 1) #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
l_scaled = min_max_scaler.fit_transform(l_val)
l_norm = pd.DataFrame(l_scaled).set_index(h.index)
l_norm.columns = ['Light']

# %%
data = [h_norm["Humidity"], t_norm['Temperature'],l_norm['Light']]
headers = ["Humidity", "Temperature","Light"]
norm = pd.concat(data, axis=1, keys=headers)

# %%
# normalize the exponential data with boxcox
# l_norm = stats.boxcox(l)
h_norm = stats.boxcox(h)
# # t_norm = stats.boxcox(t)
# h_norm = preprocessing.normalize([h])
# t_norm = preprocessing.normalize([t])

# %%
figsize=(15, 6)
norm['Humidity'].plot(label='Humidity')
norm['Temperature'].plot(label='Temperature')
norm['Light'].plot(label='Light')
plt.legend()
plt.plot()
# Out:
# []

# %%
# plot both together to compare
fig, ax=plt.subplots(1,2)
# sns.distplot(l, ax=ax[0])
# sns.distplot(h, ax=ax[0])
sns.distplot(h, ax=ax[0])
ax[0].set_title("Original Data")
# sns.distplot(l_norm[0], ax=ax[1])
# sns.distplot(h_norm[0], ax=ax[1])
sns.distplot(h_norm[0], ax=ax[1])
ax[1].set_title("Normalized data")
# Out:
# Text(0.5, 1.0, 'Normalized data')

# %%
# rcParams['figure.figsize'] = 18, 8
# 
# fig, ax = plt.subplots(1, figsize=(18, 8))
# ax.plot(data.Close)
# ax.axvline(dt.datetime(2020, 2, 2), color='red')
# plt.show()

hum_dc = sm.tsa.seasonal_decompose(norm['Humidity'], model='additive',period=10)
temp_dc = sm.tsa.seasonal_decompose(norm['Temperature'], model='additive',period=10)
light_dc = sm.tsa.seasonal_decompose(norm['Light'], model='additive',period=10)
# fig = hum_dc.plot(),temp_dc.plot()

hum_dc.plot()
temp_dc.plot()
light_dc.plot()
plt.show()

# %%
hum_dc.observed.plot(label='Humidity')
temp_dc.observed.plot(label='Temperature')
light_dc.observed.plot(label='Light')
plt.legend()
plt.show()

# %%
hum_dc.resid.plot(label='Humidity')
temp_dc.resid.plot(label='Temperature')
light_dc.resid.plot(label='Light')
plt.legend()
# plt.savefig('resid.png')
plt.show()

# %%
hum_dc

# %%
hum_dc.seasonal.plot(label='Humidity')
temp_dc.seasonal.plot(label='Temperature')
light_dc.seasonal.plot(label='Light')
plt.legend()
# plt.savefig('seasonality.png')
plt.show()

# %%
hum_dc.trend.plot(label='Humidity')
temp_dc.trend.plot(label='Temperature')
light_dc.trend.plot(label='Light')
plt.legend()
# plt.savefig('trend.png')
plt.show()
